# %%
import pandas as pd
from scipy.spatial import distance
import numpy as np

# %%
feat = pd.read_csv(r'C:\Users\lttso\Desktop\feature_task.csv')

# %%
conj = pd.read_csv(r'C:\Users\lttso\Desktop\conjunction_task.csv')

# %%
feat
# Out:
#        participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                 2    0    NaN       0     0       b/y         0       80
# 1                 2    0    NaN       0     0       b/y         0       80
# 2                 2    0    NaN       0     0       b/y         0       80
# 3                 2    0    NaN       0     0       b/y         0       80
# 4                 2    0    NaN       0     0       b/y         0       80
# ...             ...  ...    ...     ...   ...       ...       ...      ...
# 13195           133    0    NaN      11     0       r/g         0       80
# 13196           133    0    NaN      11     0       r/g         0       80
# 13197           133    0    NaN      11     0       r/g         0       80
# 13198           133    0    NaN      11     0       r/g         0       80
# 13199           133    0    NaN      11     0       r/g         0       80
#
#        proportion  timelimit  ... closest_same_target closest_other_taget  \
# 0              50        0.0  ...    [728.32, 560.21]    [704.12, 673.25]
# 1              50        0.0  ...    [614.81, 576.11]    [633.57, 669.46]
# 2              50        0.0  ...    [614.81, 576.11]    [563.11, 518.31]
# 3              50        0.0  ...    [575.55, 590.94]    [563.11, 518.31]
# 4              50        0.0  ...    [633.57, 669.46]    [575.55, 590.94]
# ...           ...        ...  ...                 ...                 ...
# 13195          50        0.0  ...     [635.09, 414.9]    [733.64, 271.54]
# 13196          50        0.0  ...    [788.75, 553.83]     [749.13, 400.0]
# 13197          50        0.0  ...     [704.2, 598.01]    [750.67, 661.48]
# 13198          50        0.0  ...     [647.96, 659.7]    [788.75, 553.83]
# 13199          50        0.0  ...    [365.22, 654.28]    [273.97, 492.51]
#
#        closest_blue_dot  closest_yellow_dot  group_selected  group_same  \
# 0      [542.49, 641.88]    [729.91, 500.11]               0           0
# 1      [799.28, 644.85]    [729.91, 500.11]               2           4
# 2      [542.49, 641.88]    [467.78, 512.95]               2           4
# 3      [542.49, 641.88]    [729.91, 500.11]               4           2
# 4      [542.49, 641.88]    [467.78, 512.95]               0           0
# ...                 ...                 ...             ...         ...
# 13195   [634.7, 333.35]    [795.52, 261.99]               0           0
# 13196  [904.86, 353.12]    [826.02, 432.72]               0           0
# 13197  [799.22, 494.15]    [723.19, 510.42]               0           0
# 13198   [872.5, 595.98]    [723.19, 510.42]               1           2
# 13199  [210.19, 588.02]     [305.76, 593.0]               3           2
#
#        group_switch  strict_line  blocked_grouped     ratio
# 0                 0            0                0  0.000000
# 1                 3            0                0  0.000000
# 2                 3            0                0 -0.022276
# 3                 3            0                0 -0.045757
# 4                 0            0                0  0.045757
# ...             ...          ...              ...       ...
# 13195             0            0                0  0.124939
# 13196             0            0                0  0.000000
# 13197             0            0                0 -0.176091
# 13198             0            0                0  0.301030
# 13199             0            0                0  0.000000
#
# [13200 rows x 42 columns]

# %%
conj
# Out:
#        participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                 2    0    NaN       0     0     rd/gs         1       80
# 1                 2    0    NaN       0     0     rd/gs         1       80
# 2                 2    0    NaN       0     0     rd/gs         1       80
# 3                 2    0    NaN       0     0     rd/gs         1       80
# 4                 2    0    NaN       0     0     rd/gs         1       80
# ...             ...  ...    ...     ...   ...       ...       ...      ...
# 13155           133    0    NaN      11     0     rd/gs         1       80
# 13156           133    0    NaN      11     0     rd/gs         1       80
# 13157           133    0    NaN      11     0     rd/gs         1       80
# 13158           133    0    NaN      11     0     rd/gs         1       80
# 13159           133    0    NaN      11     0     rd/gs         1       80
#
#        proportion  timelimit  ... closest_same_target closest_other_target  \
# 0              50        0.0  ...    [730.59, 518.69]     [749.79, 652.45]
# 1              50        0.0  ...    [629.53, 508.08]     [879.09, 638.73]
# 2              50        0.0  ...    [738.33, 265.48]     [887.28, 431.53]
# 3              50        0.0  ...    [646.24, 430.11]     [629.53, 508.08]
# 4              50        0.0  ...    [816.06, 291.74]       [826.8, 425.4]
# ...           ...        ...  ...                 ...                  ...
# 13155          50        0.0  ...    [209.15, 499.94]     [297.34, 441.21]
# 13156          50        0.0  ...    [230.74, 633.05]     [400.08, 651.14]
# 13157          50        0.0  ...     [284.3, 643.15]      [146.9, 554.92]
# 13158          50        0.0  ...    [309.17, 511.85]     [469.48, 557.46]
# 13159          50        0.0  ...    [379.79, 338.14]     [285.01, 205.82]
#
#        closest_dist_same_color  closest_dist_same_shape  grouping_selected  \
# 0             [892.28, 581.91]         [822.91, 552.75]                  1
# 1             [822.91, 552.75]         [812.32, 656.37]                  0
# 2             [813.98, 505.94]         [786.45, 330.27]                  0
# 3             [727.23, 577.05]         [728.88, 445.54]                  2
# 4             [919.61, 354.29]         [880.84, 489.44]                  1
# ...                        ...                      ...                ...
# 13155         [393.55, 486.93]         [294.81, 579.88]                  0
# 13156         [393.55, 486.93]         [294.81, 579.88]                  0
# 13157         [393.55, 486.93]          [226.6, 584.88]                  0
# 13158         [393.55, 486.93]         [294.81, 579.88]                  0
# 13159         [301.73, 124.36]         [140.29, 205.39]                  1
#
#        grouping_same  grouping_switch  strict_line  blocked_grouped     ratio
# 0                  2                0            0                0 -0.021189
# 1                  0                0            0                0  0.000000
# 2                  0                0            0                0 -0.022276
# 3                  3                3            0                0  0.000000
# 4                  2                2            0                0 -0.023481
# ...              ...              ...          ...              ...       ...
# 13155              0                0            0                0  0.301030
# 13156              0                0            0                0  0.176091
# 13157              0                0            0                0  0.000000
# 13158              0                0            0                0 -0.301030
# 13159              4                1            0                0  0.000000
#
# [13160 rows x 42 columns]

# %% [markdown]
# ### Delete '[  ]' from each row in coord coluns (for changing to float)

# %%
feat['resp_pos'] = feat['resp_pos'].str[1:-1]
feat['closest_same_target'] = feat['closest_same_target'].str[1:-1]
feat['closest_other_target'] = feat['closest_other_taget'].str[1:-1]
feat['closest_blue_dot'] = feat['closest_blue_dot'].str[1:-1]
feat['closest_yellow_dot'] = feat['closest_yellow_dot'].str[1:-1]

# %%
conj['resp_pos'] = conj['resp_pos'].str[1:-1]
conj['closest_same_target'] = conj['closest_same_target'].str[1:-1]
conj['closest_other_target'] = conj['closest_other_target'].str[1:-1]
conj['closest_dist_same_color'] = conj['closest_dist_same_color'].str[1:-1]
conj['closest_dist_same_shape'] = conj['closest_dist_same_shape'].str[1:-1]

# %% [markdown]
# ### Change type of coord 'str' to 'float'

# %%
feat['resp_pos'] = feat['resp_pos'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_same_target'] = feat['closest_same_target'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_other_target'] = feat['closest_other_target'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_blue_dot'] = feat['closest_blue_dot'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_yellow_dot'] = feat['closest_yellow_dot'].apply(lambda x: [float(y) for y in x.split(',')])

# %%
conj['resp_pos'] = conj['resp_pos'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_same_target'] = conj['closest_same_target'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_other_target'] = conj['closest_other_target'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_dist_same_color'] = conj['closest_dist_same_color'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_dist_same_shape'] = conj['closest_dist_same_shape'].apply(lambda x: [float(y) for y in x.split(',')])

# %% [markdown]
# ### Make columns with coord as np array

# %%
feat['cl_same'] = ((np.array(feat['resp_pos'].values.tolist())
                              - np.array(feat['closest_same_target']
                                         .values
                                         .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_other'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_other_target']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_blue'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_blue_dot']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_yellow'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_yellow_dot']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5

# %%
conj['cl_same'] = ((np.array(conj['resp_pos'].values.tolist())
                              - np.array(conj['closest_same_target']
                                         .values
                                         .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_other'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_other_target']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_same_color'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_dist_same_color']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_same_shape'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_dist_same_shape']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5

# %%
conj
# Out:
#        participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                 2    0    NaN       0     0     rd/gs         1       80
# 1                 2    0    NaN       0     0     rd/gs         1       80
# 2                 2    0    NaN       0     0     rd/gs         1       80
# 3                 2    0    NaN       0     0     rd/gs         1       80
# 4                 2    0    NaN       0     0     rd/gs         1       80
# ...             ...  ...    ...     ...   ...       ...       ...      ...
# 13155           133    0    NaN      11     0     rd/gs         1       80
# 13156           133    0    NaN      11     0     rd/gs         1       80
# 13157           133    0    NaN      11     0     rd/gs         1       80
# 13158           133    0    NaN      11     0     rd/gs         1       80
# 13159           133    0    NaN      11     0     rd/gs         1       80
#
#        proportion  timelimit  ... grouping_selected grouping_same  \
# 0              50        0.0  ...                 1             2
# 1              50        0.0  ...                 0             0
# 2              50        0.0  ...                 0             0
# 3              50        0.0  ...                 2             3
# 4              50        0.0  ...                 1             2
# ...           ...        ...  ...               ...           ...
# 13155          50        0.0  ...                 0             0
# 13156          50        0.0  ...                 0             0
# 13157          50        0.0  ...                 0             0
# 13158          50        0.0  ...                 0             0
# 13159          50        0.0  ...                 1             4
#
#        grouping_switch  strict_line  blocked_grouped     ratio     cl_same  \
# 0                    0            0                0 -0.021189  190.949867
# 1                    0            0                0  0.000000  187.896686
# 2                    0            0                0 -0.022276  182.760355
# 3                    3            0                0  0.000000  122.316552
# 4                    2            0                0 -0.023481  156.887006
# ...                ...          ...              ...       ...         ...
# 13155                0            0                0  0.301030  100.726603
# 13156                0            0                0  0.176091   54.503978
# 13157                0            0                0  0.000000   54.503978
# 13158                0            0                0 -0.301030  104.503072
# 13159                1            0                0  0.000000  226.072236
#
#          cl_other  cl_same_color  cl_same_shape
# 0      130.025876      58.330854     102.707121
# 1      130.025876     123.639089      62.652752
# 2       60.789862      81.553933     103.333632
# 3      101.615430      58.456644      73.169984
# 4       60.789862      83.733186      58.266986
# ...           ...            ...            ...
# 13155   71.623729      87.982901      69.529062
# 13156  116.055368     190.631191      64.136986
# 13157  114.601233     218.765058      48.347580
# 13158   72.365282      80.431308     103.741688
# 13159   76.269919     110.853565      72.729280
#
# [13160 rows x 46 columns]

# %% [markdown]
# #### Drop unuseful columns with coordinates

# %%
feat = feat.drop(['closest_same_target', 'closest_other_target', 'closest_other_taget', 'closest_blue_dot', 'closest_yellow_dot'], axis=1)

# %%
feat = feat[feat.switches != 2]

# %%
conj = conj.drop(['closest_same_target', 'closest_other_target', 'closest_dist_same_color', 'closest_dist_same_shape'], axis=1)

# %%
conj = conj[conj.switches != 2]

# %%
conj
# Out:
#        participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 1                 2    0    NaN       0     0     rd/gs         1       80
# 2                 2    0    NaN       0     0     rd/gs         1       80
# 3                 2    0    NaN       0     0     rd/gs         1       80
# 4                 2    0    NaN       0     0     rd/gs         1       80
# 5                 2    0    NaN       0     0     rd/gs         1       80
# ...             ...  ...    ...     ...   ...       ...       ...      ...
# 13155           133    0    NaN      11     0     rd/gs         1       80
# 13156           133    0    NaN      11     0     rd/gs         1       80
# 13157           133    0    NaN      11     0     rd/gs         1       80
# 13158           133    0    NaN      11     0     rd/gs         1       80
# 13159           133    0    NaN      11     0     rd/gs         1       80
#
#        proportion  timelimit  ... grouping_selected grouping_same  \
# 1              50        0.0  ...                 0             0
# 2              50        0.0  ...                 0             0
# 3              50        0.0  ...                 2             3
# 4              50        0.0  ...                 1             2
# 5              50        0.0  ...                 2             3
# ...           ...        ...  ...               ...           ...
# 13155          50        0.0  ...                 0             0
# 13156          50        0.0  ...                 0             0
# 13157          50        0.0  ...                 0             0
# 13158          50        0.0  ...                 0             0
# 13159          50        0.0  ...                 1             4
#
#        grouping_switch  strict_line  blocked_grouped     ratio     cl_same  \
# 1                    0            0                0  0.000000  187.896686
# 2                    0            0                0 -0.022276  182.760355
# 3                    3            0                0  0.000000  122.316552
# 4                    2            0                0 -0.023481  156.887006
# 5                    2            0                0 -0.048305  111.162591
# ...                ...          ...              ...       ...         ...
# 13155                0            0                0  0.301030  100.726603
# 13156                0            0                0  0.176091   54.503978
# 13157                0            0                0  0.000000   54.503978
# 13158                0            0                0 -0.301030  104.503072
# 13159                1            0                0  0.000000  226.072236
#
#          cl_other  cl_same_color  cl_same_shape
# 1      130.025876     123.639089      62.652752
# 2       60.789862      81.553933     103.333632
# 3      101.615430      58.456644      73.169984
# 4       60.789862      83.733186      58.266986
# 5       82.045966      48.593343     109.702712
# ...           ...            ...            ...
# 13155   71.623729      87.982901      69.529062
# 13156  116.055368     190.631191      64.136986
# 13157  114.601233     218.765058      48.347580
# 13158   72.365282      80.431308     103.741688
# 13159   76.269919     110.853565      72.729280
#
# [12831 rows x 42 columns]

# %% [markdown]
# #### Make csv files for 'feat', 'conj', 'feat_conj'

# %%
feat.to_csv(r'C:\Users\lttso\Desktop\feat.csv', index = False)

# %%
conj.to_csv(r'C:\Users\lttso\Desktop\conj.csv', index = False)

# %%
#feat_conj = feat.append(conj, sort=False)

# %%
#feat_conj.to_csv(r'C:\Users\User\Desktop\feat_conj.csv', index = False)

# %% [markdown]
# #### Filling Na with the -1 value in 'feat_conj'

# %%
#both = pd.read_csv(r'C:\Users\User\Desktop\feat_conj.csv')

# %%
#both['cl_blue'] = both['cl_blue'].fillna(-1).astype(float)
#both['cl_yellow'] = both['cl_yellow'].fillna(-1).astype(float)
#both['cl_same_color'] = both['cl_same_color'].fillna(-1).astype(float)
#both['cl_same_shape'] = both['cl_same_shape'].fillna(-1).astype(float)

# %% [markdown]
# #### Make a final file for 'feat_conj'

# %%
#both.to_csv(r'C:\Users\User\Desktop\feat_conj.csv', index = False)
