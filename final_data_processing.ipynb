# %%
import pandas as pd
from scipy.spatial import distance
import numpy as np

# %%
feat = pd.read_csv(r'C:\Users\lttso\Desktop\feature_task.csv')

# %%
conj = pd.read_csv(r'C:\Users\lttso\Desktop\conjunction_task.csv')

# %%
feat
# Out:
#       participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                2   49      m       0     0       r/g         0       40
# 1                2   49      m       0     0       r/g         0       40
# 2                2   49      m       0     0       r/g         0       40
# 3                2   49      m       0     0       r/g         0       40
# 4                2   49      m       0     0       r/g         0       40
# ...            ...  ...    ...     ...   ...       ...       ...      ...
# 2099            11   33      m       9     0       b/y         0       40
# 2100            11   33      m       9     0       b/y         0       40
# 2101            11   33      m       9     0       b/y         0       40
# 2102            11   33      m       9     0       b/y         0       40
# 2103            11   33      m       9     0       b/y         0       40
#
#       proportion  timelimit  ... error switches  changeScreen  \
# 0             50        0.0  ...     0        2             2
# 1             50        0.0  ...     0        1             2
# 2             50        0.0  ...     0        1             2
# 3             50        0.0  ...     0        0             2
# 4             50        0.0  ...     0        1             2
# ...          ...        ...  ...   ...      ...           ...
# 2099          50        0.0  ...     0        1             0
# 2100          50        0.0  ...     0        0             0
# 2101          50        0.0  ...     0        1             0
# 2102          50        0.0  ...     0        1             0
# 2103          50        0.0  ...     0        0             0
#
#               resp_pos  closest_same_target  closest_other_taget  \
# 0     [120.22, 672.86]      [285.3, 594.37]     [205.81, 598.29]
# 1     [205.81, 598.29]     [451.58, 595.88]      [285.3, 594.37]
# 2      [285.3, 594.37]     [120.22, 672.86]     [205.81, 598.29]
# 3     [110.68, 404.71]     [109.76, 266.01]     [120.28, 357.29]
# 4     [120.28, 357.29]     [308.05, 128.76]     [110.68, 404.71]
# ...                ...                  ...                  ...
# 2099  [385.35, 642.07]      [483.64, 646.0]     [491.96, 497.94]
# 2100   [483.64, 646.0]     [275.09, 648.33]     [491.96, 497.94]
# 2101  [719.11, 567.01]      [705.85, 346.7]     [889.77, 668.22]
# 2102  [889.77, 668.22]     [890.15, 432.35]     [719.11, 567.01]
# 2103  [890.15, 432.35]     [889.77, 668.22]      [705.85, 346.7]
#
#       closest_blue_dot  closest_yellow_dot  crowd  strict_line
# 0      [233.0, 322.97]    [467.91, 663.78]      0            0
# 1      [233.0, 322.97]    [467.91, 663.78]      1            1
# 2      [233.0, 322.97]    [467.91, 663.78]      0            0
# 3      [233.0, 322.97]    [318.47, 204.98]      0            1
# 4      [233.0, 322.97]    [318.47, 204.98]      1            1
# ...                ...                 ...    ...          ...
# 2099  [209.64, 512.86]    [555.85, 479.57]      0            1
# 2100  [625.14, 399.28]    [555.85, 479.57]      0            1
# 2101  [827.52, 581.08]    [721.61, 642.85]      1            1
# 2102  [827.52, 581.08]    [821.43, 653.61]      0            1
# 2103  [906.41, 490.65]    [825.54, 499.83]      0            1
#
# [2104 rows x 38 columns]

# %%
conj
# Out:
#       participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                2   49      m       0     0     rs/gd         1       40
# 1                2   49      m       0     0     rs/gd         1       40
# 2                2   49      m       0     0     rs/gd         1       40
# 3                2   49      m       0     0     rs/gd         1       40
# 4                2   49      m       0     0     rs/gd         1       40
# ...            ...  ...    ...     ...   ...       ...       ...      ...
# 2106            11   33      m      12     0     rs/gd         1       40
# 2107            11   33      m      12     0     rs/gd         1       40
# 2108            11   33      m      12     0     rs/gd         1       40
# 2109            11   33      m      12     0     rs/gd         1       40
# 2110            11   33      m      12     0     rs/gd         1       40
#
#       proportion  timelimit  ... error switches  changeScreen  \
# 0             50        0.0  ...     0        2             0
# 1             50        0.0  ...     0        1             0
# 2             50        0.0  ...     0        0             0
# 3             50        0.0  ...     0        1             0
# 4             50        0.0  ...     0        1             0
# ...          ...        ...  ...   ...      ...           ...
# 2106          50        0.0  ...     0        0             0
# 2107          50        0.0  ...     0        0             0
# 2108          50        0.0  ...     0        1             0
# 2109          50        0.0  ...     0        0             0
# 2110          50        0.0  ...     0        1             0
#
#               resp_pos  closest_same_target  closest_other_target  \
# 0      [743.96, 95.48]      [565.77, 327.1]      [538.29, 200.83]
# 1     [796.89, 357.27]     [905.66, 411.54]      [879.56, 509.54]
# 2     [905.66, 411.54]     [796.89, 357.27]      [879.56, 509.54]
# 3     [879.56, 509.54]     [534.68, 402.25]      [905.66, 411.54]
# 4     [893.39, 663.17]     [710.97, 578.09]      [879.56, 509.54]
# ...                ...                  ...                   ...
# 2106   [627.16, 438.5]     [900.71, 507.81]      [543.24, 403.99]
# 2107  [621.53, 362.26]      [627.16, 438.5]      [543.24, 403.99]
# 2108  [910.49, 430.44]     [543.24, 403.99]      [900.71, 507.81]
# 2109   [888.22, 214.9]     [910.49, 430.44]       [706.61, 125.4]
# 2110   [406.61, 665.1]      [627.16, 438.5]      [540.57, 662.37]
#
#       closest_dist_same_color  closest_dist_same_shape  crowd  strict_line
# 0            [490.24, 185.96]         [699.83, 180.13]      0            1
# 1            [743.46, 358.26]         [798.19, 480.71]      1            1
# 2            [905.12, 579.24]          [921.42, 326.0]      1            1
# 3            [798.19, 480.71]         [905.12, 579.24]      0            1
# 4            [905.12, 579.24]         [798.19, 480.71]      1            1
# ...                       ...                      ...    ...          ...
# 2106         [731.11, 507.42]         [792.88, 401.91]      0            0
# 2107         [488.36, 278.73]         [579.86, 198.01]      0            0
# 2108         [792.88, 401.91]         [822.71, 510.44]      1            1
# 2109         [910.98, 289.61]         [822.71, 510.44]      1            1
# 2110          [286.57, 568.3]         [470.09, 571.08]      0            1
#
# [2111 rows x 38 columns]

# %% [markdown]
# ### Delete '[  ]' from each row in coord coluns (for changing to float)

# %%
feat['resp_pos'] = feat['resp_pos'].str[1:-1]
feat['closest_same_target'] = feat['closest_same_target'].str[1:-1]
feat['closest_other_target'] = feat['closest_other_taget'].str[1:-1]
feat['closest_blue_dot'] = feat['closest_blue_dot'].str[1:-1]
feat['closest_yellow_dot'] = feat['closest_yellow_dot'].str[1:-1]

# %%
conj['resp_pos'] = conj['resp_pos'].str[1:-1]
conj['closest_same_target'] = conj['closest_same_target'].str[1:-1]
conj['closest_other_target'] = conj['closest_other_target'].str[1:-1]
conj['closest_dist_same_color'] = conj['closest_dist_same_color'].str[1:-1]
conj['closest_dist_same_shape'] = conj['closest_dist_same_shape'].str[1:-1]

# %% [markdown]
# ### Change type of coord 'str' to 'float'

# %%
feat['resp_pos'] = feat['resp_pos'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_same_target'] = feat['closest_same_target'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_other_target'] = feat['closest_other_target'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_blue_dot'] = feat['closest_blue_dot'].apply(lambda x: [float(y) for y in x.split(',')])
feat['closest_yellow_dot'] = feat['closest_yellow_dot'].apply(lambda x: [float(y) for y in x.split(',')])

# %%
conj['resp_pos'] = conj['resp_pos'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_same_target'] = conj['closest_same_target'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_other_target'] = conj['closest_other_target'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_dist_same_color'] = conj['closest_dist_same_color'].apply(lambda x: [float(y) for y in x.split(',')])
conj['closest_dist_same_shape'] = conj['closest_dist_same_shape'].apply(lambda x: [float(y) for y in x.split(',')])

# %% [markdown]
# ### Make columns with coord as np array

# %%
feat['cl_same'] = ((np.array(feat['resp_pos'].values.tolist())
                              - np.array(feat['closest_same_target']
                                         .values
                                         .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_other'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_other_target']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_blue'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_blue_dot']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
feat['cl_yellow'] = ((np.array(feat['resp_pos'].values.tolist()) 
                                 - np.array(feat['closest_yellow_dot']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5

# %%
conj['cl_same'] = ((np.array(conj['resp_pos'].values.tolist())
                              - np.array(conj['closest_same_target']
                                         .values
                                         .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_other'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_other_target']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_same_color'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_dist_same_color']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5
conj['cl_same_shape'] = ((np.array(conj['resp_pos'].values.tolist()) 
                                 - np.array(conj['closest_dist_same_shape']
                                            .values
                                            .tolist()))**2).sum(axis=1) ** 0.5

# %%
conj
# Out:
#       participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 0                2   49      m       0     0     rs/gd         1       40
# 1                2   49      m       0     0     rs/gd         1       40
# 2                2   49      m       0     0     rs/gd         1       40
# 3                2   49      m       0     0     rs/gd         1       40
# 4                2   49      m       0     0     rs/gd         1       40
# ...            ...  ...    ...     ...   ...       ...       ...      ...
# 2106            11   33      m      12     0     rs/gd         1       40
# 2107            11   33      m      12     0     rs/gd         1       40
# 2108            11   33      m      12     0     rs/gd         1       40
# 2109            11   33      m      12     0     rs/gd         1       40
# 2110            11   33      m      12     0     rs/gd         1       40
#
#       proportion  timelimit  ... closest_same_target closest_other_target  \
# 0             50        0.0  ...     [565.77, 327.1]     [538.29, 200.83]
# 1             50        0.0  ...    [905.66, 411.54]     [879.56, 509.54]
# 2             50        0.0  ...    [796.89, 357.27]     [879.56, 509.54]
# 3             50        0.0  ...    [534.68, 402.25]     [905.66, 411.54]
# 4             50        0.0  ...    [710.97, 578.09]     [879.56, 509.54]
# ...          ...        ...  ...                 ...                  ...
# 2106          50        0.0  ...    [900.71, 507.81]     [543.24, 403.99]
# 2107          50        0.0  ...     [627.16, 438.5]     [543.24, 403.99]
# 2108          50        0.0  ...    [543.24, 403.99]     [900.71, 507.81]
# 2109          50        0.0  ...    [910.49, 430.44]      [706.61, 125.4]
# 2110          50        0.0  ...     [627.16, 438.5]     [540.57, 662.37]
#
#       closest_dist_same_color  closest_dist_same_shape  crowd  strict_line  \
# 0            [490.24, 185.96]         [699.83, 180.13]      0            1
# 1            [743.46, 358.26]         [798.19, 480.71]      1            1
# 2            [905.12, 579.24]          [921.42, 326.0]      1            1
# 3            [798.19, 480.71]         [905.12, 579.24]      0            1
# 4            [905.12, 579.24]         [798.19, 480.71]      1            1
# ...                       ...                      ...    ...          ...
# 2106         [731.11, 507.42]         [792.88, 401.91]      0            0
# 2107         [488.36, 278.73]         [579.86, 198.01]      0            0
# 2108         [792.88, 401.91]         [822.71, 510.44]      1            1
# 2109         [910.98, 289.61]         [822.71, 510.44]      1            1
# 2110          [286.57, 568.3]         [470.09, 571.08]      0            1
#
#          cl_same    cl_other  cl_same_color  cl_same_shape
# 0     292.231929  231.081742     269.370505      95.462450
# 1     121.557171  173.264197      53.439171     123.446845
# 2     121.557171  101.416024     167.700869      86.979706
# 3     361.183275  101.416024      86.326391      74.238828
# 4     201.285029  154.251242      84.745724     205.802555
# ...          ...         ...            ...            ...
# 2106  282.194044   90.738671     124.721966     169.711362
# 2107   76.447593   88.717061     157.198950     169.453390
# 2108  368.201256   77.985674     121.020961     118.765855
# 2109  216.687435  202.465904      78.099947     302.713481
# 2110  316.211737  133.987815     154.207139     113.443690
#
# [2111 rows x 42 columns]

# %% [markdown]
# #### Drop unuseful columns with coordinates

# %%
feat = feat.drop(['closest_same_target', 'closest_other_target', 'closest_other_taget', 'closest_blue_dot', 'closest_yellow_dot'], axis=1)

# %%
feat = feat[feat.switches != 2]

# %%
conj = conj.drop(['closest_same_target', 'closest_other_target', 'closest_dist_same_color', 'closest_dist_same_shape'], axis=1)

# %%
conj = conj[conj.switches != 2]

# %%
conj
# Out:
#       participantN  age gender  trialN  task condition  FeatConj  setSize  \
# 1                2   49      m       0     0     rs/gd         1       40
# 2                2   49      m       0     0     rs/gd         1       40
# 3                2   49      m       0     0     rs/gd         1       40
# 4                2   49      m       0     0     rs/gd         1       40
# 5                2   49      m       0     0     rs/gd         1       40
# ...            ...  ...    ...     ...   ...       ...       ...      ...
# 2106            11   33      m      12     0     rs/gd         1       40
# 2107            11   33      m      12     0     rs/gd         1       40
# 2108            11   33      m      12     0     rs/gd         1       40
# 2109            11   33      m      12     0     rs/gd         1       40
# 2110            11   33      m      12     0     rs/gd         1       40
#
#       proportion  timelimit  ... error switches  changeScreen  \
# 1             50        0.0  ...     0        1             0
# 2             50        0.0  ...     0        0             0
# 3             50        0.0  ...     0        1             0
# 4             50        0.0  ...     0        1             0
# 5             50        0.0  ...     0        0             0
# ...          ...        ...  ...   ...      ...           ...
# 2106          50        0.0  ...     0        0             0
# 2107          50        0.0  ...     0        0             0
# 2108          50        0.0  ...     0        1             0
# 2109          50        0.0  ...     0        0             0
# 2110          50        0.0  ...     0        1             0
#
#               resp_pos  crowd  strict_line     cl_same    cl_other  \
# 1     [796.89, 357.27]      1            1  121.557171  173.264197
# 2     [905.66, 411.54]      1            1  121.557171  101.416024
# 3     [879.56, 509.54]      0            1  361.183275  101.416024
# 4     [893.39, 663.17]      1            1  201.285029  154.251242
# 5     [710.97, 578.09]      2            1  113.394865  181.993655
# ...                ...    ...          ...         ...         ...
# 2106   [627.16, 438.5]      0            0  282.194044   90.738671
# 2107  [621.53, 362.26]      0            0   76.447593   88.717061
# 2108  [910.49, 430.44]      1            1  368.201256   77.985674
# 2109   [888.22, 214.9]      1            1  216.687435  202.465904
# 2110   [406.61, 665.1]      0            1  316.211737  133.987815
#
#       cl_same_color  cl_same_shape
# 1         53.439171     123.446845
# 2        167.700869      86.979706
# 3         86.326391      74.238828
# 4         84.745724     205.802555
# 5        100.934859     130.729464
# ...             ...            ...
# 2106     124.721966     169.711362
# 2107     157.198950     169.453390
# 2108     121.020961     118.765855
# 2109      78.099947     302.713481
# 2110     154.207139     113.443690
#
# [2000 rows x 38 columns]

# %% [markdown]
# #### Make csv files for 'feat', 'conj', 'feat_conj'

# %%
feat.to_csv(r'C:\Users\lttso\Desktop\feat.csv', index = False)

# %%
conj.to_csv(r'C:\Users\lttso\Desktop\conj.csv', index = False)

# %%
#feat_conj = feat.append(conj, sort=False)

# %%
#feat_conj.to_csv(r'C:\Users\User\Desktop\feat_conj.csv', index = False)

# %% [markdown]
# #### Filling Na with the -1 value in 'feat_conj'

# %%
#both = pd.read_csv(r'C:\Users\User\Desktop\feat_conj.csv')

# %%
#both['cl_blue'] = both['cl_blue'].fillna(-1).astype(float)
#both['cl_yellow'] = both['cl_yellow'].fillna(-1).astype(float)
#both['cl_same_color'] = both['cl_same_color'].fillna(-1).astype(float)
#both['cl_same_shape'] = both['cl_same_shape'].fillna(-1).astype(float)

# %% [markdown]
# #### Make a final file for 'feat_conj'

# %%
#both.to_csv(r'C:\Users\User\Desktop\feat_conj.csv', index = False)
